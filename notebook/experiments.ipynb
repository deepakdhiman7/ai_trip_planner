# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
import os
os.chdir("..")  # adjust if notebook is nested deeper

# %%
from utils.model_loader import ModelLoader
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader = ModelLoader()
llm = loader.load_llm()

output = llm.invoke("what is capex meaning?")
# Out:
# Loading LLM from Groq..............

# %%
print(output.content)
# Out:
# **CAPEX** stands for **Capital Expenditure**.
#
# ### What It Means
# - **Capital expenditures** are funds that a company (or government, organization, etc.) spends to **acquire, upgrade, or maintain physical assets** that will provide benefits **over a period longer than one year**.
# - These assets can be tangible (like machinery, buildings, vehicles) or intangible (like patents, software licenses) but must have a useful life extending beyond the current fiscal year.
#
# ### How It’s Treated in Accounting
# | Aspect | CAPEX | OPEX (Operating Expenditure) |
# |--------|-------|------------------------------|
# | **Purpose** | Invest in long‑term assets | Cover day‑to‑day operating costs |
# | **Accounting** | Capitalized on the balance sheet; cost is **depreciated** or **amortized** over the asset’s useful life | Expensed immediately on the income statement |
# | **Impact on Cash Flow** | Shows up in the **investing cash‑flow** section of the cash‑flow statement | Appears in the **operating cash‑flow** section |
# | **Examples** | Purchase of a new factory, installation of solar panels, buying a fleet of trucks, software development that will be used for several years | Salaries, rent, utilities, routine maintenance, office supplies |
#
# ### Why CAPEX Matters
# 1. **Strategic Growth** – Large CAPEX projects often signal expansion, modernization, or a shift in business strategy (e.g., building a new production line).
# 2. **Financial Health** – Analysts watch CAPEX trends to gauge a company’s long‑term investment appetite and cash‑flow sustainability.
# 3. **Tax Implications** – Because CAPEX is depreciated, it affects taxable income over multiple years rather than all at once.
# 4. **Budgeting & Planning** – CAPEX requires detailed planning, approval processes, and often financing (debt or equity), unlike most OPEX which is covered by regular operating budgets.
#
# ### Typical CAPEX Items (Examples)
# - **Manufacturing:** New machinery, plant construction, equipment upgrades.
# - **Technology:** Data centers, servers, enterprise software licenses (if capitalized), R&D equipment.
# - **Infrastructure:** Roads, bridges, utilities, telecommunications towers.
# - **Real Estate:** Purchase or major renovation of office buildings, warehouses, retail locations.
# - **Intangible Assets:** Patents, trademarks, long‑term software development projects (when criteria for capitalization are met).
#
# ### How Companies Report CAPEX
# - **Cash‑flow Statement:** Listed under “Investing Activities” as “Purchase of property, plant and equipment (PP&E)” or similar.
# - **Balance Sheet:** Capitalized as **PP&E** (Property, Plant & Equipment) or other long‑term asset categories.
# - **Notes to Financial Statements:** Provide details on the amount spent, the nature of the assets, and the depreciation/amortization methods used.
#
# ### Quick Mnemonic
# > **C**apital **A**ssets **P**rovide **E**xtra **X**tra‑year benefits.
#
# In short, CAPEX is the money a business puts into assets that will help it generate revenue **now and in the future**, rather than just covering the costs of running day‑to‑day operations.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(output)
#
# NameError: name 'output' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a.method_init()
#
# Cell In[5], line 3, in XYZ.method_init(self)
#       2     def method_init(self):
# ----> 3         self.var2 = "xyz"
#
# File ~\projects\agentic_ai\ai_trip_planner\.venv\Lib\site-packages\pydantic\main.py:1048, in BaseModel.__setattr__(self, name, value)
#    1046     setattr_handler(self, name, value)
#    1047 # if None is returned from _setattr_handler, the attribute was set directly
# -> 1048 elif (setattr_handler := self._setattr_handler(name, value)) is not None:
#    1049     setattr_handler(self, name, value)  # call here to not memo on possibly unknown fields
#    1050     self.__pydantic_setattr_handlers__[name] = setattr_handler
#
# File ~\projects\agentic_ai\ai_trip_planner\.venv\Lib\site-packages\pydantic\main.py:1095, in BaseModel._setattr_handler(self, name, value)
#    1092 elif name not in cls.__pydantic_fields__:
#    1093     if cls.model_config.get('extra') != 'allow':
#    1094         # TODO - matching error
# -> 1095         raise ValueError(f'"{cls.__name__}" object has no field "{name}"')
#    1096     elif attr is None:
#    1097         # attribute does not exist, so put it in extra
#    1098         self.__pydantic_extra__[name] = value
#
# ValueError: "XYZ" object has no field "var2"
